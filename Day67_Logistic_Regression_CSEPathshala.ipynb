# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Samrat-Ashok-Technology-Internship/blob/main/Day67_Logistic_Regression_CSEPathshala.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Logistic Regression is another technique borrowed by machine learning from field of statistics.
#
# - It is the go-to method for binary classification problems (with two class values).
#
# - In this post you will discover the logistic regression algorithm for machine learning.

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
df = pd.read_csv("")
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df['education'] = df['education'].fillna(1.0)
df['cigsPerDay'] = df['cigsPerDay'].fillna(0.0)
df['BPMeds'] = df['BPMeds'].fillna(0.0)

# %%
t_mean = df['totChol'].mean()
df['totChol'] = df['totChol'].fillna(t_mean)
t_mean

# %%
b_mean = df['BMI'].mean()
df['BMI'] = df['BMI'].fillna(b_mean)
b_mean

# %%
g_mean = df['glucose'].mean()
df['glucose'] = df['glucose'].fillna(g_mean)
g_mean

# %%
h_mean = df['heartRate'].mean()
df['heartRate'] = df['heartRate'].fillna(h_mean)
h_mean

# %%
df.rename(columns={'male':'gender'}, inplace=True)
df.head()

# %% [markdown]
# ### **Logistic Regression**

# %%
X = df.drop('TenYearCHD', axis=1)
y = df['TenYearCHD']

# %%
X_train, X_test, y_train, y_test = train_test_spli(X, y, test_size=0.25, random_state=42)
 
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
logreg = LogisticRegression(max_iter=20000).fit(X_train, y_train)
logreg.score(X_train, y_train)

# %%
prediction = logreg.predict(X_test)
prediction

# %%
print("\nAccuracy score :-\n", accuracy_score(y_test, prediction, normalize=True))
print("\nClassification report :-\n", classification_report(y_test, prediction))
print("\nConfusion Matrix :-\n", confusion_matrix(y_test, prediction))

# %% [markdown]
# ### **Reference**

# %% [markdown]
# - https://www.youtube.com/watch?v=dN_BjpaCBCA&list=PLzx-_kRo3HZtP3tWaieUPwAh9K4I00_6p&index=67
