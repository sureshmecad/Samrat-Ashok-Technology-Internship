# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Samrat-Ashok-Technology-Internship/blob/main/Day59_Stochastic_Gradient_Descent_CSEPathshala.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - **SGDC:** Stochastic Gradient Descent

# %% [markdown]
# ![11.png](data:image/png;base64,...)

# %%
import numpy as np
from sklearn.linear_model import SGDClassifier, SGDRegressor

# %%
X = np.array([[-1, -1], [-2, -1], [1, 1], [2, 1]])
y = np.array([1, 1, 2, 2])

# %%
clf = SGDClassifier(max_iter=1000, tol=1e-3, penalty="elasticnet")
clf.fit(X, y)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None,
#               penalty='elasticnet', power_t=0.5, random_state=None,
#               shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#               warm_start=False)

# %%
clf.predict([[2,2]])
# Out:
# array([2])

# %%
clf.coef_
# Out:
# array([[9.77200712, 9.77200712]])

# %%
clf.intercept_
# Out:
# array([-10.])

# %%
clf1 = SGDRegressor(max_iter=1000,penalty="elasticnet",loss='huber',tol=1e-3, average=True)
clf1.fit(X, y)
# Out:
# SGDRegressor(alpha=0.0001, average=True, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='huber', max_iter=1000,
#              n_iter_no_change=5, penalty='elasticnet', power_t=0.25,
#              random_state=None, shuffle=True, tol=0.001,
#              validation_fraction=0.1, verbose=0, warm_start=False)

# %%
clf1.coef_
# Out:
# array([-0.00164713, -0.00106165])

# %% [markdown]
# #### **Reference**
#
# - https://www.youtube.com/watch?v=9e5H7wCA-WI&list=PLzx-_kRo3HZtP3tWaieUPwAh9K4I00_6p&index=69
