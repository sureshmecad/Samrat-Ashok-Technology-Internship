# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Samrat-Ashok-Technology-Internship/blob/main/Day49_Pandas_DataFrame_CSEPathshala.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Dataframe**
#
# - A pandas dataframe is a two-dimensional Numpy like library.
#
# - It can be visualized as a table.
#
# - An individual column in dataframe (together with the index) is a series.

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Creating a DataFrame**
#
# - We can create a pandas dataframe using the DataFrame() class.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(10,4), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0  0.729512  0.787458 -0.591967  0.517503
# 1 -0.354464  0.671761  0.921846  0.519475
# 2 -0.725776 -0.483790  1.237066  0.640795
# 3  0.536603  0.167631  0.600133 -0.522019
# 4 -1.036336  0.234892 -0.566709 -0.643341
# 5 -0.475471  0.138364 -0.925397 -0.490096
# 6 -0.572803  1.253132 -2.065901  0.368964
# 7  0.342683  0.146518  0.383948  0.659211
# 8  1.383292  0.933858  0.825973  1.045420
# 9 -0.811412 -2.146001  1.902883 -0.955608

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Heart Disease.zip")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %% [markdown]
# **specifying the index in a dataframe**
#
# - Notice that the dataframe printed in the previous examples has an index starting from 0.
#
# - This is similar to that of a series.
#
# - Like a series, you can also set the index for the dataframe using the index property.

# %%
days = pd.date_range('20190525', periods=303)
df.index = days
df
# Out:
#             age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  target
# 2019-05-25   63    1   3       145   233  ...      2.3      0   0     1       1
# 2019-05-26   37    1   2       130   250  ...      3.5      0   0     2       1
# 2019-05-27   41    0   1       130   204  ...      1.4      2   0     2       1
# 2019-05-28   56    1   1       120   236  ...      0.8      2   0     2       1
# 2019-05-29   57    0   0       120   354  ...      0.6      2   0     2       1
# ...         ...  ...  ..       ...   ...  ...      ...    ...  ..   ...     ...
# 2020-03-18   57    0   0       140   241  ...      0.2      1   0     3       0
# 2020-03-19   45    1   3       110   264  ...      1.2      1   0     3       0
# 2020-03-20   68    1   0       144   193  ...      3.4      1   2     3       0
# 2020-03-21   57    1   0       130   131  ...      1.2      1   1     3       0
# 2020-03-22   57    0   1       130   236  ...      0.0      1   1     2       0
#
# ...

# %%
days = pd.date_range('20190525', periods=303)
df.index = days
print(df)
print(df.index)
# Out:
#             age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  target
# 2019-05-25   63    1   3       145   233  ...      2.3      0   0     1       1
# 2019-05-26   37    1   2       130   250  ...      3.5      0   0     2       1
# 2019-05-27   41    0   1       130   204  ...      1.4      2   0     2       1
# 2019-05-28   56    1   1       120   236  ...      0.8      2   0     2       1
# 2019-05-29   57    0   0       120   354  ...      0.6      2   0     2       1
# ...         ...  ...  ..       ...   ...  ...      ...    ...  ..   ...     ...
# 2020-03-18   57    0   0       140   241  ...      0.2      1   0     3       0
# 2020-03-19   45    1   3       110   264  ...      1.2      1   0     3       0
# 2020-03-20   68    1   0       144   193  ...      3.4      1   2     3       0
# 2020-03-21   57    1   0       130   131  ...      1.2      1   1     3       0
# 2020-03-22   57    0   1       130   236  ...      0.0      1   1     2       0
#
# ...

# %% [markdown]
# - If you want to get the values of the entire DataFrame as a two-dimensional ndarray, use the values property.

# %%
days = pd.date_range('20190525', periods=303)
df.index = days
df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %% [markdown]
# #### **Reference**
#
# - https://www.youtube.com/watch?v=du5jOUxoVOM&list=PLzx-_kRo3HZtP3tWaieUPwAh9K4I00_6p&index=31
